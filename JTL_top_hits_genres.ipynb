# %%
#Website for csv file: https://www.kaggle.com/datasets/paradisejoy/top-hits-spotify-from-20002019

# %%
#dependencies
import os
import csv
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# File to Load 
top_hits = Path("Resources/top_hits_2000-2019.csv")

# %%
#Data File and store into Pandas DataFrames
top_hits_df = pd.read_csv(top_hits)
top_hits_df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
#sort the year column in ascending order
sorted_df = top_hits_df.sort_values('year', ascending=True)
# Out:
#               artist                     song  duration_ms  explicit  year  \
# 44     Missy Elliott                 Hot Boyz       215466      True  1998
# 82     Savage Garden           Crash and Burn       281466     False  1999
# 123       Crazy Town                Butterfly       216733     False  1999
# 34    Britney Spears   Born to Make You Happy       243533     False  1999
# 35    Montell Jordan         Get It On Tonite       276266     False  1999
# ...              ...                      ...          ...       ...   ...
# 333         Lil' Kim              Magic Stick       359973      True  2019
# 1999     Post Malone                  Circles       215280     False  2019
# 568       Will Smith                   Switch       197666     False  2020
# 308         t.A.T.u.  All The Things She Said       214440      True  2020
# 1991             NSG                  Options       240081      True  2020
#
# ...

# %%
#check get unique genres 
unique_genres = sorted_df['genre'].unique()
unique_genres
# Out:
# array(['hip hop, pop, R&B', 'pop', 'rock, metal', 'Dance/Electronic',
#        'pop, latin', 'hip hop', 'pop, rock, metal', 'set()', 'pop, R&B',
#        'rock', 'rock, blues, latin', 'hip hop, pop', 'rock, pop',
#        'pop, country', 'pop, Dance/Electronic',
#        'rock, Folk/Acoustic, easy listening', 'pop, rock', 'hip hop, R&B',
#        'World/Traditional, Folk/Acoustic', 'hip hop, pop, latin',
#        'rock, pop, metal', 'metal', 'pop, Folk/Acoustic', 'R&B',
#        'Folk/Acoustic, rock', 'hip hop, Dance/Electronic',
#        'hip hop, pop, rock', 'rock, easy listening', 'Folk/Acoustic, pop',
#        'pop, R&B, Dance/Electronic', 'World/Traditional, hip hop',
#        'hip hop, pop, R&B, latin', 'pop, easy listening, jazz',
#        'rock, blues', 'pop, rock, Dance/Electronic',
#        'World/Traditional, rock', 'latin',
#        'World/Traditional, pop, Folk/Acoustic', 'country',
#        'hip hop, pop, country', 'rock, Dance/Electronic',
# ...

# %%
#count the number of genres
num_genres = len(unique_genres)
num_genres
# Out:
# 59

# %%
#split genre columns into separate columns
top_hits_df[["genre 1", "genre 2", "genre 3", "genre 4"]] = top_hits_df.genre.str.split(",", expand=True)
top_hits_df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  ...  \
# ...

# %%
#check unique genre in genre 1
unique_genre_1 = top_hits_df['genre 1'].unique()
unique_genre_1
# Out:
# array(['pop', 'rock', 'hip hop', 'Dance/Electronic', 'metal', 'R&B',
#        'Folk/Acoustic', 'set()', 'World/Traditional', 'latin', 'country',
#        'easy listening'], dtype=object)

# %%
#rename 'set()' to "Unknown"
top_hits_clean = top_hits_df.replace('set()', 'unknown')
top_hits_clean
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  ...  \
# ...

# %%
#check set() has been properly renamed
unique_genre = top_hits_clean['genre 1'].unique()
unique_genre
# Out:
# array(['pop', 'rock', 'hip hop', 'Dance/Electronic', 'metal', 'R&B',
#        'Folk/Acoustic', 'unknown', 'World/Traditional', 'latin',
#        'country', 'easy listening'], dtype=object)

# %%
#create new dataframe with only columns year, genre, and songs
new_df = pd.DataFrame(top_hits_clean[['year', 'genre 1','song']])
new_df

#filter dataframe for years 2000 to 2020
year_filter = new_df[(new_df['year'] >= 2000) & (new_df['year'] <= 2019)]
year_filter
# Out:
#       year  genre 1                                    song
# 0     2000      pop                  Oops!...I Did It Again
# 3     2000     rock                            It's My Life
# 4     2000      pop                             Bye Bye Bye
# 6     2000  hip hop                     The Real Slim Shady
# 7     2000      pop                                 Rock DJ
# ...    ...      ...                                     ...
# 1995  2019      pop                                  Sucker
# 1996  2019      pop                            Cruel Summer
# 1997  2019  hip hop                              The Git Up
# 1998  2019      pop  Dancing With A Stranger (with Normani)
# 1999  2019  hip hop                                 Circles
#
# [1958 rows x 3 columns]

# %%
# Group the data by year and genre and calculate the count for each genre
top_year_genre = year_filter.groupby(['year', 'genre 1']).count()
top_year_genre = top_year_genre.reset_index()
top_year_genre
# Out:
#      year            genre 1  song
# 0    2000   Dance/Electronic     1
# 1    2000      Folk/Acoustic     1
# 2    2000                R&B     3
# 3    2000  World/Traditional     1
# 4    2000            hip hop    21
# ..    ...                ...   ...
# 120  2019   Dance/Electronic     1
# 121  2019            hip hop    38
# 122  2019              latin     6
# 123  2019                pop    43
# 124  2019            unknown     1
#
# [125 rows x 3 columns]

# %%
# Group the data by year and genre, and calculate the count for each genre
top_year_genre = year_filter.groupby(['year', 'genre 1']).count()
# Pivot the data to get the counts of songs by year and genre
pivoted_genres = top_year_genre.pivot_table(index='year', columns='genre 1', values='song', aggfunc='sum')

#plot the data
pivoted_genres.plot(kind='bar', stacked=True, figsize=(15,10))
plt.xlabel('Year')
plt.ylabel('Count of Genres')
plt.title('Popularity of Genres from 2000 to 2019')
plt.legend(loc = 'best')

# %%
#filter to contain only 2008
year_2008 = new_df[(new_df['year'] == 2008)]

#group by genre then get total song count in each genre
year_2008_groupby = year_2008.groupby('genre 1').count()

#drop year column
year_2008_clean = year_2008_groupby.drop(columns=['year'])
year_2008_clean
# Out:
#                   song
# genre 1
# Dance/Electronic     2
# R&B                  2
# hip hop             35
# pop                 47
# rock                11

# %%
#check data type for year_2008_clean
year_2008_clean.dtypes
# Out:
# song    int64
# dtype: object

# %%
#pie chart of generes in 2008
labels = ['Dance/Electronic', 'R&B','Hip hop','Pop', 'Rock']
colors = ["orange", "blue", "pink", 'green', "red"]
sizes =["2","2","35","47","11"]
plt.pie(sizes, labels=labels, colors=colors, autopct="%1.1f%%", startangle=140)
plt.title('Popular Genres in 2008')
# Out:
# Text(0.5, 1.0, 'Popular Genres in 2008')

# %%
#filter to contain only 2008
year_2019 = new_df[(new_df['year'] == 2019)]
year_2019
# Out:
#       year  genre 1                                      song
# 194   2019      pop                                     Crazy
# 214   2019      pop  If I Could Go! (feat. Lil' Mo & Sacario)
# 217   2019  hip hop                             Rock The Boat
# 244   2019      pop                             Just A Little
# 333   2019  hip hop                               Magic Stick
# ...    ...      ...                                       ...
# 1995  2019      pop                                    Sucker
# 1996  2019      pop                              Cruel Summer
# 1997  2019  hip hop                                The Git Up
# 1998  2019      pop    Dancing With A Stranger (with Normani)
# 1999  2019  hip hop                                   Circles
#
# [89 rows x 3 columns]

# %%
#group by genre then get total song count in each genre
year_2019_groupby = year_2019.groupby('genre 1').count()
year_2019_groupby
# Out:
#                   year  song
# genre 1
# Dance/Electronic     1     1
# hip hop             38    38
# latin                6     6
# pop                 43    43
# unknown              1     1

# %%
#drop year column
year_2019_clean = year_2019_groupby.drop(columns=['year'])
year_2019_clean
# Out:
#                   song
# genre 1
# Dance/Electronic     1
# hip hop             38
# latin                6
# pop                 43
# unknown              1

# %%
labels = ['Dance/Electronic', 'Hip hop','Latin', 'Pop', 'Unknown']
colors = ["orange", "pink", "purple", 'green', "yellow"]
sizes =["1","38","6","43","1"]
plt.pie(sizes, labels=labels, colors=colors, autopct="%1.1f%%", startangle=140)
plt.title('Popular Genres in 2008')
# Out:
# Text(0.5, 1.0, 'Popular Genres in 2008')
