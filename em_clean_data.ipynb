# %%
import pandas as pd

# %%
#read hcctad.txt file and make into dataframe
hcctad_pd = pd.read_csv("../hcctad.txt", delimiter=',')
hcctad_pd
# Out:
#                         Variable  Year Australia Austria Belgium Canada  \
# 0                     Population  1788         .       .       .      .
# 1                     Population  1789         .       .       .      .
# 2                     Population  1790         .       .       .      .
# 3                     Population  1791         .       .       .      .
# 4                     Population  1792         .       .       .      .
# ...                          ...   ...       ...     ...     ...    ...
# 17115  Legislative effectiveness  1997         .       .       .      .
# 17116  Legislative effectiveness  1998         .       .       .      .
# 17117  Legislative effectiveness  1999         .       .       .      .
# 17118  Legislative effectiveness  2000         .       .       .      .
# 17119  Legislative effectiveness  2001         .       .       .      .
#
#       Denmark Finland France Germany  ... Luxembourg Netherlands New Zealand  \
# ...
