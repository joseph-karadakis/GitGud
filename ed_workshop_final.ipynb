# %%
#Dependencies
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read from "SpotifyTop200_Final.csv" for all Data Vizzes
spot_top_200 = pd.read_csv("Output/SpotifyTop200_Final.csv")
spot_top_200
# Out:
#       Unnamed: 0                 title  rank
# 0              0                     !    13  \
# 1              1     "42" - From SR3MM   130
# 2              2   #PROUDCATOWNERREMIX    89
# 3              3    $$$ - with Matt Ox   147
# 4              4        'Til You Can't   153
# ...          ...                   ...   ...
# 7538        7538    ¿Donde Has Estado?   125
# 7539        7539       ¿Quien Tu Eres?   135
# 7540        7540       Échame La Culpa   195
# 7541        7541  ‘tis the damn season   131
# 7542        7542                 美女と野獣    82
#
#                                   artist
# 0                           Trippie Redd  \
# 1     Rae Sremmurd, Swae Lee, Slim Jxmmi
# 2               XXXTENTACION, Rico Nasty
# 3                           XXXTENTACION
# 4                           Cody Johnson
# ...                                  ...
# 7538                      Eslabon Armado
# 7539                           Bad Bunny
# 7540             Luis Fonsi, Demi Lovato
# 7541                        Taylor Swift
# 7542          Ariana Grande, John Legend
#
#                                                     url         region
# 0     https://open.spotify.com/track/5a1ofLoPiAn5xxf...  United States  \
# 1     https://open.spotify.com/track/5lf91lPnGKtIqsg...  United States
# 2     https://open.spotify.com/track/5dkZ2DrcPJrqwlR...  United States
# 3     https://open.spotify.com/track/65u1dHQyQyE4y4a...  United States
# 4     https://open.spotify.com/track/4k3lPl8YTKuY8c1...  United States
# ...                                                 ...            ...
# 7538  https://open.spotify.com/track/6hklGK8K5sqP4IK...  United States
# 7539  https://open.spotify.com/track/6kN06eEOblRAuWI...  United States
# 7540  https://open.spotify.com/track/1zsG4eaZmkA1dvj...  United States
# 7541  https://open.spotify.com/track/4GBkffrtA51p17J...  United States
# 7542  https://open.spotify.com/track/1KT0xdIjm7t053x...  United States
#
#        chart      trend   streams        Spotify Track Id  ...  mode
# 0     top200  NEW_ENTRY  808145.0  5a1ofLoPiAn5xxf5UE6472  ...     1  \
# 1     top200  NEW_ENTRY  297731.0  5lf91lPnGKtIqsgmG1z8Ip  ...     1
# 2     top200  NEW_ENTRY  361205.0  5dkZ2DrcPJrqwlRQe6Q35e  ...     1
# 3     top200    MOVE_UP  198304.0  65u1dHQyQyE4y4aN2eDmMF  ...     0
# 4     top200  NEW_ENTRY  249850.0  4k3lPl8YTKuY8c1HelVnm3  ...     1
# ...      ...        ...       ...                     ...  ...   ...
# 7538  top200  NEW_ENTRY  282014.0  6hklGK8K5sqP4IK2PZHGkV  ...     0
# 7539  top200  NEW_ENTRY  370883.0  6kN06eEOblRAuWI0xUUS91  ...     0
# 7540  top200  MOVE_DOWN  195750.0  1zsG4eaZmkA1dvjDDsAGLK  ...     1
# 7541  top200  MOVE_DOWN  258559.0  4GBkffrtA51p17JH35irGA  ...     1
# 7542  top200  NEW_ENTRY  279628.0  1KT0xdIjm7t053xByACrrg  ...     1
#
#       speechiness acousticness  instrumentalness  liveness  valence  tempo
# 0          0.0841      0.02960          0.000000     0.177    0.693    120  \
# 1          0.1250      0.00275          0.000000     0.108    0.324    131
# 2          0.3900      0.02870          0.000041     0.127    0.235    146
# 3          0.0650      0.06360          0.000000     0.138    0.508    141
# 4          0.0436      0.05130          0.000000     0.106    0.460    161
# ...           ...          ...               ...       ...      ...    ...
# 7538       0.0310      0.74200          0.000000     0.135    0.325    126
# 7539       0.1360      0.18500          0.000004     0.125    0.325    138
# 7540       0.0411      0.03220          0.000000     0.097    0.640     97
# 7541       0.0311      0.73700          0.000054     0.105    0.351    146
# 7542       0.0266      0.12600          0.000000     0.103    0.283     82
#
#       duration_mins  year  month
# 0              2.26  2019      8
# 1              3.97  2018      5
# 2              2.62  2019      8
# 3              2.17  2018      4
# 4              3.74  2021     10
# ...             ...   ...    ...
# 7538           4.87  2020      7
# 7539           2.65  2018     12
# 7540           2.90  2018      3
# 7541           3.83  2021      1
# 7542           3.80  2017      2
#
# [7543 rows x 24 columns]

# %%
#test DataFrame condensation with small sample.
jan_2021 = spot_top_200.loc[spot_top_200['year']==2021]
jan_2021 = jan_2021.loc[jan_2021['month']==1]
jan_2021
# Out:
#       Unnamed: 0                                              title  rank
# 131          131  34+35 Remix (feat. Doja Cat, Megan Thee Stalli...     2  \
# 195          195                                                865     6
# 276          276                                          Accordion    94
# 282          282               Adderall (Corvette Corvette) - Remix    87
# 331          331                                           All Caps   104
# ...          ...                                                ...   ...
# 7459        7459              right where you left me - bonus track   101
# 7501        7501                       this is how you fall in love    92
# 7504        7504                                        tolerate it   124
# 7525        7525                                             willow    24
# 7541        7541                               ‘tis the damn season   131
#
#                              artist
# 131                   Ariana Grande  \
# 195                   Morgan Wallen
# 276     Madvillain, Madlib, MF DOOM
# 282        Popp Hunna, Lil Uzi Vert
# 331     Madvillain, Madlib, MF DOOM
# ...                             ...
# 7459                   Taylor Swift
# 7501  Jeremy Zucker, Chelsea Cutler
# 7504                   Taylor Swift
# 7525                   Taylor Swift
# 7541                   Taylor Swift
#
#                                                     url         region
# 131   https://open.spotify.com/track/3jjBPF4NDMCU51p...  United States  \
# 195   https://open.spotify.com/track/0sKEilrw1GrBlG6...  United States
# 276   https://open.spotify.com/track/5jAvbp8kEnRPToi...  United States
# 282   https://open.spotify.com/track/7s95nPLMfiLTPoQ...  United States
# 331   https://open.spotify.com/track/1Y2ExJJ9Dmb9po8...  United States
# ...                                                 ...            ...
# 7459  https://open.spotify.com/track/3zwMVvkBe2qIKDO...  United States
# 7501  https://open.spotify.com/track/0742PcMPo2Akmo4...  United States
# 7504  https://open.spotify.com/track/0PurA4JVJ8YQgSV...  United States
# 7525  https://open.spotify.com/track/3Uo7WG0vmLQ07WB...  United States
# 7541  https://open.spotify.com/track/4GBkffrtA51p17J...  United States
#
#        chart      trend    streams        Spotify Track Id  ...  mode
# 131   top200  NEW_ENTRY  1619016.0  3jjBPF4NDMCU51psU8JPpR  ...     1  \
# 195   top200  NEW_ENTRY   907152.0  0sKEilrw1GrBlG6qsTCrP4  ...     1
# 276   top200  NEW_ENTRY   295698.0  5jAvbp8kEnRPToi4Bzcvzt  ...     0
# 282   top200  MOVE_DOWN   308068.0  7s95nPLMfiLTPoQ7pqUFmO  ...     0
# 331   top200  NEW_ENTRY   287457.0  1Y2ExJJ9Dmb9po8K0ybSj3  ...     1
# ...      ...        ...        ...                     ...  ...   ...
# 7459  top200  NEW_ENTRY   331312.0  3zwMVvkBe2qIKDObWgXw4N  ...     1
# 7501  top200  NEW_ENTRY   335471.0  0742PcMPo2Akmo4vHC29VZ  ...     1
# 7504  top200  NEW_ENTRY   234542.0  0PurA4JVJ8YQgSVopY8fn6  ...     1
# 7525  top200  MOVE_DOWN   515959.0  3Uo7WG0vmLQ07WB4BDwy7D  ...     1
# 7541  top200  MOVE_DOWN   258559.0  4GBkffrtA51p17JH35irGA  ...     1
#
#       speechiness acousticness  instrumentalness  liveness  valence  tempo
# 131        0.3040       0.2050          0.000000    0.2270    0.726    110  \
# 195        0.0248       0.7230          0.000000    0.1010    0.367     89
# 276        0.3090       0.0243          0.000000    0.0665    0.716     97
# 282        0.2990       0.2170          0.000000    0.1890    0.677    142
# 331        0.3350       0.2660          0.000015    0.1720    0.666     86
# ...           ...          ...               ...       ...      ...    ...
# 7459       0.0282       0.7690          0.000106    0.1170    0.645    138
# 7501       0.0355       0.7330          0.000025    0.1260    0.274     80
# 7504       0.0488       0.8780          0.000027    0.0797    0.221     75
# 7525       0.1640       0.8350          0.001790    0.1450    0.549     81
# 7541       0.0311       0.7370          0.000054    0.1050    0.351    146
#
#       duration_mins  year  month
# 131            3.04  2021      1
# 195            3.18  2021      1
# 276            1.98  2021      1
# 282            2.94  2021      1
# 331            2.17  2021      1
# ...             ...   ...    ...
# 7459           4.08  2021      1
# 7501           2.91  2021      1
# 7504           4.09  2021      1
# 7525           3.58  2021      1
# 7541           3.83  2021      1
#
# [102 rows x 24 columns]

# %%
#test scatter plot w/ test DataFrame
jan_2021.plot.scatter(x = 'danceability', y = 'energy')
# Out:
# <Axes: xlabel='danceability', ylabel='energy'>

# %%
#create Antithesis function that will determine the inverse of a given dataframe's song attributes
def antithesis(df):
    print('Regular Averages:')
    print('-----------------')
    print(f"Danceability: {df['danceability'].mean()}")
    print(f"Energy: {df['energy'].mean()}")
    print(f"Instrumentalness: {df['instrumentalness'].mean()}")
    print(f"Speechiness: {df['speechiness'].mean()}")
    print(f"Acousticness: {df['acousticness'].mean()}")
    print(f"Liveness: {df['liveness'].mean()}")
    print(f"Valence: {df['valence'].mean()}\n")

    print('Antithesis Averages:')
    print('-----------------')
    print(f"Danceability: {1-df['danceability'].mean()}")
    print(f"Energy: {1-df['energy'].mean()}")
    print(f"Instrumentalness: {1-df['instrumentalness'].mean()}")
    print(f"Speechiness: {1-df['speechiness'].mean()}")
    print(f"Acousticness: {1-df['acousticness'].mean()}")
    print(f"Liveness: {1-df['liveness'].mean()}")
    print(f"Valence: {1-df['valence'].mean()}")

# %%
#testing antithesis function
antithesis(jan_2021)
# Out:
# Regular Averages:
# -----------------
# Danceability: 0.636450980392157
# Energy: 0.6276431372549021
# Instrumentalness: 0.015588749313725489
# Speechiness: 0.10534705882352943
# Acousticness: 0.3280851568627451
# Liveness: 0.17178529411764706
# Valence: 0.5149088235294118
#
# Antithesis Averages:
# -----------------
# Danceability: 0.363549019607843
# Energy: 0.37235686274509794
# Instrumentalness: 0.9844112506862746
# Speechiness: 0.8946529411764705
# Acousticness: 0.6719148431372549
# Liveness: 0.8282147058823529
# Valence: 0.4850911764705882

# %%
spot_top_200.columns
# Out:
# Index(['Unnamed: 0', 'title', 'rank', 'artist', 'url', 'region', 'chart',
#        'trend', 'streams', 'Spotify Track Id', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_mins', 'year', 'month'],
#       dtype='object')

# %%
#creating bigger sample, using whole year
yr_2021 = spot_top_200.loc[spot_top_200['year']==2021]
yr_2021
# Out:
#       Unnamed: 0                                              title  rank
# 4              4                                     'Til You Can't   153  \
# 6              6            'Zat You, Santa Claus? - Single Version   135
# 12            12                   (Sittin' On) the Dock of the Bay   178
# 13            13  (There's No Place Like) Home for the Holidays ...   170
# 18            18  ...And to Those I Love, Thanks for Sticking Ar...   193
# ...          ...                                                ...   ...
# 7526        7526                          willow - 90's trend remix   140
# 7529        7529                                            working   196
# 7530        7530                                     worst behavior    34
# 7533        7533                                 you broke me first   141
# 7541        7541                               ‘tis the damn season   131
#
#                                artist
# 4                        Cody Johnson  \
# 6     Louis Armstrong, The Commanders
# 12                       Otis Redding
# 13                         Perry Como
# 18                        $uicideboy$
# ...                               ...
# 7526                     Taylor Swift
# 7529               Tate McRae, Khalid
# 7530                    Ariana Grande
# 7533                       Tate McRae
# 7541                     Taylor Swift
#
#                                                     url         region
# 4     https://open.spotify.com/track/4k3lPl8YTKuY8c1...  United States  \
# 6     https://open.spotify.com/track/1ig71VFfrkWqjZz...  United States
# 12    https://open.spotify.com/track/3zBhihYUHBmGd2b...  United States
# 13    https://open.spotify.com/track/0hvN2v6fAcB6xWy...  United States
# 18    https://open.spotify.com/track/30QR0ndUdiiMQMA...  United States
# ...                                                 ...            ...
# 7526  https://open.spotify.com/track/77p4fRpoeiZMtUy...  United States
# 7529  https://open.spotify.com/track/31sSFHIe4NaxltV...  United States
# 7530  https://open.spotify.com/track/6KIKaWKE9wV6mLj...  United States
# 7533  https://open.spotify.com/track/45bE4HXI0AwGZXf...  United States
# 7541  https://open.spotify.com/track/4GBkffrtA51p17J...  United States
#
#        chart      trend   streams        Spotify Track Id  ...  mode
# 4     top200  NEW_ENTRY  249850.0  4k3lPl8YTKuY8c1HelVnm3  ...     1  \
# 6     top200  NEW_ENTRY  380051.0  1ig71VFfrkWqjZzGXzoqOd  ...     0
# 12    top200  NEW_ENTRY  224572.0  3zBhihYUHBmGd2bcQIobrF  ...     1
# 13    top200  MOVE_DOWN  282080.0  0hvN2v6fAcB6xWyW7UaooA  ...     1
# 18    top200  NEW_ENTRY  201946.0  30QR0ndUdiiMQMA9g1PGCm  ...     1
# ...      ...        ...       ...                     ...  ...   ...
# 7526  top200  NEW_ENTRY  250055.0  77p4fRpoeiZMtUy3P9kN21  ...     1
# 7529  top200  MOVE_DOWN  214877.0  31sSFHIe4NaxltVFOEIcTa  ...     1
# 7530  top200  NEW_ENTRY  436728.0  6KIKaWKE9wV6mLjho3w61y  ...     0
# 7533  top200    MOVE_UP  253986.0  45bE4HXI0AwGZXfZtMp8JR  ...     1
# 7541  top200  MOVE_DOWN  258559.0  4GBkffrtA51p17JH35irGA  ...     1
#
#       speechiness acousticness  instrumentalness  liveness  valence  tempo
# 4          0.0436       0.0513          0.000000    0.1060   0.4600    161  \
# 6          0.3210       0.3330          0.000000    0.4630   0.6830    123
# 12         0.0312       0.6840          0.000016    0.0810   0.5350    104
# 13         0.0511       0.8970          0.000000    0.2580   0.4740    144
# 18         0.0409       0.1240          0.000090    0.1400   0.1110    114
# ...           ...          ...               ...       ...      ...    ...
# 7526       0.0741       0.3130          0.000000    0.0872   0.3790    169
# 7529       0.0588       0.2820          0.000000    0.0833   0.5120    107
# 7530       0.0617       0.3700          0.000000    0.1180   0.4340    101
# 7533       0.0500       0.7850          0.000000    0.0906   0.0823    125
# 7541       0.0311       0.7370          0.000054    0.1050   0.3510    146
#
#       duration_mins  year  month
# 4              3.74  2021     10
# 6              2.79  2021     12
# 12             2.73  2021     11
# 13             2.93  2021     12
# 18             2.81  2021      7
# ...             ...   ...    ...
# 7526           3.75  2021      6
# 7529           3.50  2021      7
# 7530           2.07  2021      2
# 7533           2.82  2021      7
# 7541           3.83  2021      1
#
# [1510 rows x 24 columns]

# %%
antithesis(yr_2021)
# Out:
# Regular Averages:
# -----------------
# Danceability: 0.6514690728476821
# Energy: 0.60441
# Instrumentalness: 0.01904491321192053
# Speechiness: 0.1405484105960265
# Acousticness: 0.2541305047682119
# Liveness: 0.17890596026490063
# Valence: 0.4686524503311258
#
# Antithesis Averages:
# -----------------
# Danceability: 0.3485309271523179
# Energy: 0.39559
# Instrumentalness: 0.9809550867880795
# Speechiness: 0.8594515894039735
# Acousticness: 0.7458694952317881
# Liveness: 0.8210940397350994
# Valence: 0.5313475496688742

# %%
#found closest match to 2021 antithesis averages, which was "Greensleeves" by "Vince Guaraldi Trio"... Still pretty good, actually.
#Could be because it's pulling from Top200 chart, so it's not accurate.
yr_2021_dan = yr_2021.loc[(yr_2021['danceability']> .25) & (yr_2021['danceability']< .45)]
yr_2021_en = yr_2021_dan.loc[(yr_2021['energy']> .29) & (yr_2021['energy']< .49)]
yr_2021_in = yr_2021_en.loc[(yr_2021['instrumentalness']> .88) & (yr_2021['instrumentalness']< 1.08)]
yr_2021_in
# Out:
#       Unnamed: 0         title  rank               artist
# 2476        2476  Greensleeves   191  Vince Guaraldi Trio  \
#
#                                                     url         region
# 2476  https://open.spotify.com/track/6qEZ3wkUF7nY1DB...  United States  \
#
#        chart      trend   streams        Spotify Track Id  ...  mode
# 2476  top200  NEW_ENTRY  285788.0  6qEZ3wkUF7nY1DBbD7DHoN  ...     0  \
#
#       speechiness acousticness  instrumentalness  liveness  valence  tempo
# 2476       0.0315        0.931             0.914     0.212      0.5    180  \
#
#       duration_mins  year  month
# 2476           5.48  2021     12
#
# [1 rows x 24 columns]

# %%
#condensing dataframe to numerical, non-boolean columns that will create Data Vizzes
df_to_plot = spot_top_200[['year','month','speechiness','instrumentalness','acousticness','liveness','valence','danceability']]
df_to_plot
# Out:
#       year  month  speechiness  instrumentalness  acousticness  liveness
# 0     2019      8       0.0841          0.000000       0.02960     0.177  \
# 1     2018      5       0.1250          0.000000       0.00275     0.108
# 2     2019      8       0.3900          0.000041       0.02870     0.127
# 3     2018      4       0.0650          0.000000       0.06360     0.138
# 4     2021     10       0.0436          0.000000       0.05130     0.106
# ...    ...    ...          ...               ...           ...       ...
# 7538  2020      7       0.0310          0.000000       0.74200     0.135
# 7539  2018     12       0.1360          0.000004       0.18500     0.125
# 7540  2018      3       0.0411          0.000000       0.03220     0.097
# 7541  2021      1       0.0311          0.000054       0.73700     0.105
# 7542  2017      2       0.0266          0.000000       0.12600     0.103
#
#       valence  danceability
# 0       0.693         0.725
# 1       0.324         0.968
# 2       0.235         0.783
# 3       0.508         0.774
# 4       0.460         0.501
# ...       ...           ...
# 7538    0.325         0.552
# 7539    0.325         0.727
# 7540    0.640         0.724
# 7541    0.351         0.575
# 7542    0.283         0.512
#
# [7543 rows x 8 columns]

# %%
#testing w/ only danceability columns for all months and years
year_means = (1-spot_top_200.groupby(['year','month'])['danceability'].mean())

year_means
# Out:
# year  month
# 2017  1        0.329785
#       2        0.321765
#       3        0.353513
#       4        0.329628
#       5        0.361600
#       6        0.351256
#       7        0.368873
#       8        0.308028
#       9        0.372395
#       10       0.316636
#       11       0.335719
#       12       0.349030
# 2018  1        0.356575
#       2        0.321734
#       3        0.283075
#       4        0.323323
#       5        0.291379
#       6        0.338370
#       7        0.292473
#       8        0.309386
#       9        0.325044
#       10       0.294134
#       11       0.346939
#       12       0.371383
# 2019  1        0.270685
#       2        0.274933
#       3        0.300103
#       4        0.313211
#       5        0.329263
#       6        0.320350
#       7        0.305525
#       8        0.338846
#       9        0.362500
#       10       0.298779
#       11       0.340096
#       12       0.380205
# 2020  1        0.302384
#       2        0.320408
#       3        0.320114
#       4        0.350853
#       5        0.277475
#       6        0.308442
#       7        0.347142
#       8        0.337540
#       9        0.315139
#       10       0.349164
#       11       0.289155
#       12       0.361305
# 2021  1        0.363549
#       2        0.348937
#       3        0.348726
#       4        0.354836
#       5        0.327278
#       6        0.284913
#       7        0.332846
#       8        0.365107
#       9        0.347943
#       10       0.336028
#       11       0.358871
#       12       0.422855
# Name: danceability, dtype: float64

# %%
#graphing test danceability year_means df
year_means.plot(kind = 'line', figsize=[10,10], grid = True ,rot= 90 ,xlabel= 'Date (by YYYY,D)', ylabel= 'Danceability')
# Out:
# <Axes: xlabel='Date (by YYYY,D)', ylabel='Danceability'>

# %%
#creates "Antithesis" averages df from condensed df_to_plot. Based off antithesis function from earlier.
plot_means = (df_to_plot.groupby(['year','month']).mean())
plot_means
# Out:
#             speechiness  instrumentalness  acousticness  liveness   valence
# year month
# 2017 1         0.124675          0.011572      0.210004  0.176335  0.483477  \
#      2         0.146601          0.005536      0.216132  0.169592  0.415461
#      3         0.168023          0.019064      0.315311  0.192136  0.498051
#      4         0.162601          0.018421      0.205485  0.223526  0.437397
#      5         0.130998          0.010059      0.192202  0.172558  0.479116
#      6         0.149221          0.010893      0.145561  0.205560  0.382702
#      7         0.151515          0.032484      0.185474  0.205747  0.431316
#      8         0.153687          0.003725      0.146140  0.179757  0.418776
#      9         0.107240          0.001315      0.137919  0.184879  0.517940
#      10        0.120960          0.015546      0.118487  0.179533  0.480816
#      11        0.130022          0.016297      0.224914  0.186776  0.388620
#      12        0.178177          0.001376      0.209335  0.227948  0.432188
# 2018 1         0.128043          0.003625      0.243954  0.156780  0.415378
#      2         0.114760          0.009879      0.211100  0.168768  0.455655
#      3         0.149882          0.005301      0.176421  0.160401  0.441876
#      4         0.123759          0.012525      0.174529  0.179317  0.447649
#      5         0.159351          0.006600      0.201103  0.171680  0.449092
#      6         0.176865          0.014206      0.201541  0.193570  0.458985
#      7         0.157751          0.001620      0.185209  0.184510  0.461829
#      8         0.142798          0.007284      0.235961  0.163812  0.420645
#      9         0.180487          0.013840      0.216460  0.190630  0.469261
#      10        0.190519          0.041776      0.199974  0.205563  0.458187
#      11        0.155563          0.010632      0.213123  0.209262  0.425028
#      12        0.140803          0.008983      0.386753  0.189631  0.487032
# 2019 1         0.172373          0.020523      0.262385  0.161704  0.417810
#      2         0.158726          0.006628      0.257653  0.159441  0.446397
#      3         0.173133          0.022269      0.212426  0.190972  0.447782
#      4         0.163053          0.031062      0.236452  0.190293  0.432403
#      5         0.153026          0.007773      0.188717  0.191111  0.496294
#      6         0.126855          0.010189      0.217754  0.181537  0.461844
#      7         0.193445          0.001947      0.271370  0.183293  0.480454
#      8         0.179689          0.057715      0.182150  0.181475  0.443604
#      9         0.118261          0.030106      0.293018  0.170085  0.454748
#      10        0.173134          0.000622      0.238423  0.151995  0.478665
#      11        0.136338          0.011293      0.299624  0.192344  0.479103
#      12        0.116833          0.028015      0.315652  0.172722  0.420769
# 2020 1         0.150773          0.003745      0.218425  0.194783  0.440298
#      2         0.182842          0.017765      0.205532  0.174642  0.504458
#      3         0.147685          0.020868      0.270564  0.184071  0.490339
#      4         0.151864          0.006857      0.216251  0.176675  0.460084
#      5         0.159290          0.007212      0.201582  0.167896  0.470869
#      6         0.157699          0.006884      0.172364  0.208791  0.477161
#      7         0.164366          0.001038      0.258345  0.195633  0.552619
#      8         0.131621          0.019957      0.265538  0.167735  0.457547
#      9         0.183580          0.036814      0.228357  0.191603  0.460734
#      10        0.134328          0.037015      0.174818  0.211829  0.465979
#      11        0.171154          0.002308      0.159302  0.183716  0.456904
#      12        0.127394          0.029597      0.257460  0.175997  0.471283
# 2021 1         0.105347          0.015589      0.328085  0.171785  0.514909
#      2         0.109971          0.071525      0.180358  0.159323  0.439521
#      3         0.150779          0.012720      0.318328  0.187725  0.458492
#      4         0.153158          0.001142      0.177437  0.174380  0.456418
#      5         0.150036          0.031904      0.154174  0.194351  0.503769
#      6         0.202533          0.009764      0.199750  0.176750  0.462423
#      7         0.134256          0.027662      0.242327  0.190853  0.498836
#      8         0.135288          0.007562      0.271425  0.188589  0.457310
#      9         0.147672          0.008812      0.263937  0.166996  0.443488
#      10        0.167330          0.019790      0.245371  0.184795  0.467444
#      11        0.108629          0.005165      0.259135  0.157502  0.451036
#      12        0.126364          0.034223      0.380668  0.181949  0.430919
#
#             danceability
# year month
# 2017 1          0.670215
#      2          0.678235
#      3          0.646487
#      4          0.670372
#      5          0.638400
#      6          0.648744
#      7          0.631127
#      8          0.691972
#      9          0.627605
#      10         0.683364
#      11         0.664281
#      12         0.650970
# 2018 1          0.643425
#      2          0.678266
#      3          0.716925
#      4          0.676677
#      5          0.708621
#      6          0.661630
#      7          0.707527
#      8          0.690614
#      9          0.674956
#      10         0.705866
#      11         0.653061
#      12         0.628617
# 2019 1          0.729315
#      2          0.725067
#      3          0.699897
#      4          0.686789
#      5          0.670737
#      6          0.679650
#      7          0.694475
#      8          0.661154
#      9          0.637500
#      10         0.701221
#      11         0.659904
#      12         0.619795
# 2020 1          0.697616
#      2          0.679592
#      3          0.679886
#      4          0.649147
#      5          0.722525
#      6          0.691558
#      7          0.652858
#      8          0.662460
#      9          0.684861
#      10         0.650836
#      11         0.710845
#      12         0.638695
# 2021 1          0.636451
#      2          0.651063
#      3          0.651274
#      4          0.645164
#      5          0.672722
#      6          0.715087
#      7          0.667154
#      8          0.634893
#      9          0.652057
#      10         0.663972
#      11         0.641129
#      12         0.577145

# %%
#creates a list of dates to use as xlabels
dates = []
for d in range(2017,2022):
    for i in range(1,13):
        dates.append(f"{i}/{d}")

plot_means.reset_index()
plot_means['xlabel']= dates
plot_means = plot_means.set_index('xlabel')
plot_means.head()
# Out:
#         speechiness  instrumentalness  acousticness  liveness   valence
# xlabel
# 1/2017     0.124675          0.011572      0.210004  0.176335  0.483477  \
# 2/2017     0.146601          0.005536      0.216132  0.169592  0.415461
# 3/2017     0.168023          0.019064      0.315311  0.192136  0.498051
# 4/2017     0.162601          0.018421      0.205485  0.223526  0.437397
# 5/2017     0.130998          0.010059      0.192202  0.172558  0.479116
#
#         danceability
# xlabel
# 1/2017      0.670215
# 2/2017      0.678235
# 3/2017      0.646487
# 4/2017      0.670372
# 5/2017      0.638400

# %%
#creates final data viz w/ all float "Antithesis" column averages, and saves it as a PNG.
graph = plot_means.plot(kind='line',figsize=(20,6),xlabel= 'Date',title='Top 200 Song Attributes',grid=True)

graph.grid(alpha = .25)
graph.legend(loc = 'lower left')
graph.set_ylim(ymin=0)


plt.savefig("Top200SongAtt.png")

# %%
#stores plot_means variable, to avoid having to redo all previous work in another workbook.
# %store plot_means
# Out:
# Stored 'plot_means' (DataFrame)
